# %%
################ CELL TRAINER ######################################

##1. Kode untuk masuk ke google drive
# from google.colab import drive
# drive.mount('/content/drive')

##2. kode untuk menampilkan isi dari folder saat ini
# !ls "/content/drive/My Drive/Coba YOLO/YOLO_Training_1"

##3. kode untuk masuk ke dalam folder tertentu
# %cd "/content/drive/My Drive/Coba YOLO/YOLO_Training_1/python"

##4. kode python untuk menampilkan teks
# print("Hello!")
# print("ini \nsebuah \nkalimat \nbersusun ke bawah")

##5. kode python untuk import library dan gambar
##import library
# import cv2
##menampilkan gambar
# !curl -o husnul_logo.png https://colab.research.google.com/img/colab_favicon_256px.png
# img = cv2.imread('husnul_logo.png', cv2.IMREAD_UNCHANGED)
# cv2_imshow(img)
##troubleshoot
# from google.colab.patches import cv2_imshow
##resize gambar 
# img = cv2.resize(img,(500,500))

##6. python untuk melakukan perhitungan
##dasar
# a = 5
# b = 3
# c = 6
# d = a+b+c
# d
# e = a*b*c
# d,e
##fungsi 
# import matplotlib.pyplot as plt
# import numpy as np
# x = np.linspace(0, 10, 100)
# plt.title("plotting fungsi")
# plt.plot(x, np.sin(x))
# plt.plot(x, np.cos(x))
# plt.show()
##plot gambar dengan matplotlib
# img = plt.imread("haha.png")
# plt.figure(figsize = (10,10))
# plt.title("Judul",fontsize = 40)
# plt.imshow(img)
# plt.show()

# 7. membuat file python dan running


# 8. kode untuk running object detection
# %run yolo.py --image "images/baggage_claim.jpg" --yolo "yolo-coco"
# %run dor.py
# Out:
# Hello World

# %%
untuk login bisa menggunakan account berikut:
email : sibernetika.agv@gmail.com
pass  : sibernetikaagv2020

# %%
################ CELL IPEH ######################################
# !ls "/content/drive/My Drive/Coba YOLO/YOLO_Training_1"
# Out:
# images	logo.png  output  videos  yolo-coco  yolo.py  yolo_video.py
